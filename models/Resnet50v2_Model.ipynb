# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_agg import FigureCanvasAgg
import tensorflow as tf
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Flatten, Rescaling, Conv2D, MaxPooling2D, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adagrad
from tensorflow.keras.losses import KLDivergence
import keras
from keras import layers

# %%
y_data = np.load(f'/content/drive/MyDrive/kaggle/y_data.npy')
y_data.shape

# %%
def build_rn_model(version=0):
  checkpoint_filepath = '/content/drive/MyDrive/kaggle/rn_model_checkpoint.h5'
  if version:
    model = Sequential()

    pretrained_model = keras.applications.ResNet50V2(
    include_top=False,
    weights="imagenet",
    input_shape=(400, 256, 3),
    pooling='average',
    classifier_activation ='softmax',
    classes=6
    )

    modified_pretrained_model = keras.Model(inputs=pretrained_model.input, outputs=pretrained_model.layers[-1].output)
    for layer in modified_pretrained_model.layers:
      layer.trainable = False

    model.add(modified_pretrained_model)
    model.add(GlobalAveragePooling2D())
    model.add(Dense(6, activation='softmax'))

    loss = KLDivergence()
    opt = Adam(learning_rate=0.00001)
    model.compile(optimizer=opt, loss=loss)

  else:
    model = load_model(checkpoint_filepath)

  return model

# %%
rn_model = build_rn_model(version=1)
rn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model_1 (Functional)        (None, 13, 8, 2048)       23564800
#
#  global_average_pooling2d_1  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 6)                 12294
#
# =================================================================
# Total params: 23577094 (89.94 MB)
# Trainable params: 12294 (48.02 KB)
# Non-trainable params: 23564800 (89.89 MB)
# _________________________________________________________________

# %%
checkpoint_filepath_v1 = '/content/drive/MyDrive/kaggle/rn_model_checkpoint_v1.h5'

batch_size=16
num_batches = 12  # Calculate total number of batches
for i in range(1, num_batches + 1):
    if i == 8713:
      batch_path = f'/content/drive/MyDrive/kaggle/X_data_batch_filtered_8713.npy'
    else:
      batch_path = f'/content/drive/MyDrive/kaggle/X_data_batch_filtered_{i*792}.npy'

    X_batch = np.load(batch_path)
    print(f'File {i}/{num_batches} loaded')
    # Split X_batch into smaller batches of size 16
    num_sub_batches = len(X_batch) // batch_size
    for j in range(num_sub_batches):
        start_idx = j * batch_size
        end_idx = (j + 1) * batch_size
        X_sub_batch = X_batch[start_idx:end_idx]
        rn_model.fit(X_sub_batch, y_data[(i-1)*len(X_batch) + start_idx:(i-1)*len(X_batch) + end_idx], epochs=1, validation_split=0.2)

    rn_model.save(checkpoint_filepath_v1)
# Out:
# File 1/12 loaded
# 1/1 [==============================] - 1s 1s/step - loss: 1.3886 - val_loss: 1.2407
# 1/1 [==============================] - 1s 1s/step - loss: 1.5566 - val_loss: 2.2391
# 1/1 [==============================] - 1s 1s/step - loss: 1.2881 - val_loss: 1.0958
# 1/1 [==============================] - 2s 2s/step - loss: 1.2120 - val_loss: 1.3153
# 1/1 [==============================] - 2s 2s/step - loss: 1.9664 - val_loss: 0.9567
# 1/1 [==============================] - 1s 1s/step - loss: 1.3426 - val_loss: 1.6569
# 1/1 [==============================] - 1s 1s/step - loss: 1.8045 - val_loss: 2.0239
# 1/1 [==============================] - 1s 1s/step - loss: 1.2994 - val_loss: 1.4035
# 1/1 [==============================] - 1s 1s/step - loss: 1.6054 - val_loss: 1.5051
# 1/1 [==============================] - 1s 1s/step - loss: 2.2999 - val_loss: 1.6352
# 1/1 [==============================] - 1s 1s/step - loss: 1.1694 - val_loss: 1.4924
# 1/1 [==============================] - 1s 1s/step - loss: 1.3341 - val_loss: 1.7107
# 1/1 [==============================] - 1s 1s/step - loss: 2.0429 - val_loss: 1.1059
# 1/1 [==============================] - 1s 1s/step - loss: 1.7726 - val_loss: 1.2606
# 1/1 [==============================] - 1s 1s/step - loss: 1.6313 - val_loss: 1.1110
# 1/1 [==============================] - 1s 1s/step - loss: 1.8333 - val_loss: 1.5025
# 1/1 [==============================] - 1s 1s/step - loss: 1.5013 - val_loss: 2.3836
# 1/1 [==============================] - 1s 1s/step - loss: 1.3357 - val_loss: 2.4360
# 1/1 [==============================] - 1s 1s/step - loss: 1.2333 - val_loss: 1.2691
# 1/1 [==============================] - 1s 1s/step - loss: 1.6457 - val_loss: 0.8855
# 1/1 [==============================] - 1s 1s/step - loss: 1.5300 - val_loss: 2.7498
# 1/1 [==============================] - 2s 2s/step - loss: 1.3972 - val_loss: 1.2484
# 1/1 [==============================] - 2s 2s/step - loss: 1.6301 - val_loss: 1.4415
# 1/1 [==============================] - 1s 1s/step - loss: 2.1696 - val_loss: 1.2279
# 1/1 [==============================] - 1s 1s/step - loss: 1.4899 - val_loss: 1.4540
# 1/1 [==============================] - 1s 1s/step - loss: 1.5276 - val_loss: 1.7852
# 1/1 [==============================] - 1s 1s/step - loss: 1.2649 - val_loss: 1.2620
# 1/1 [==============================] - 1s 1s/step - loss: 1.6389 - val_loss: 3.8982
# 1/1 [==============================] - 1s 1s/step - loss: 1.8431 - val_loss: 1.2907
# 1/1 [==============================] - 1s 1s/step - loss: 0.9740 - val_loss: 0.9741
# 1/1 [==============================] - 2s 2s/step - loss: 1.4006 - val_loss: 1.6323
# 1/1 [==============================] - 1s 1s/step - loss: 1.1356 - val_loss: 2.1828
# 1/1 [==============================] - 1s 1s/step - loss: 1.6362 - val_loss: 1.8662
# 1/1 [==============================] - 1s 1s/step - loss: 1.5339 - val_loss: 1.2063
# 1/1 [==============================] - 1s 1s/step - loss: 1.9879 - val_loss: 1.1064
# 1/1 [==============================] - 1s 1s/step - loss: 1.7871 - val_loss: 1.8672
# 1/1 [==============================] - 2s 2s/step - loss: 1.4821 - val_loss: 1.7342
# 1/1 [==============================] - 1s 1s/step - loss: 1.2019 - val_loss: 2.2703
# 1/1 [==============================] - 1s 1s/step - loss: 1.5540 - val_loss: 1.7279
# 1/1 [==============================] - 2s 2s/step - loss: 1.9518 - val_loss: 1.2347
# 1/1 [==============================] - 1s 1s/step - loss: 1.3126 - val_loss: 0.9647
# 1/1 [==============================] - 2s 2s/step - loss: 1.4392 - val_loss: 1.7214
# 1/1 [==============================] - 2s 2s/step - loss: 1.3979 - val_loss: 2.4874
# 1/1 [==============================] - 1s 1s/step - loss: 1.3486 - val_loss: 1.3373
# 1/1 [==============================] - 1s 1s/step - loss: 1.8059 - val_loss: 1.7939
# 1/1 [==============================] - 1s 1s/step - loss: 1.5199 - val_loss: 1.0149
# 1/1 [==============================] - 2s 2s/step - loss: 1.7550 - val_loss: 1.4118
# 1/1 [==============================] - 2s 2s/step - loss: 1.8966 - val_loss: 1.4148
# 1/1 [==============================] - 2s 2s/step - loss: 1.1862 - val_loss: 1.6648
# File 2/12 loaded
# 1/1 [==============================] - 2s 2s/step - loss: 1.5689 - val_loss: 1.3280
# 1/1 [==============================] - 1s 1s/step - loss: 1.5303 - val_loss: 1.4245
# 1/1 [==============================] - 2s 2s/step - loss: 1.7656 - val_loss: 1.4042
# 1/1 [==============================] - 2s 2s/step - loss: 1.6848 - val_loss: 1.3092
# 1/1 [==============================] - 1s 1s/step - loss: 1.6574 - val_loss: 1.7278
# 1/1 [==============================] - 1s 1s/step - loss: 1.7067 - val_loss: 1.2836
# 1/1 [==============================] - 1s 1s/step - loss: 1.3608 - val_loss: 1.6696
# 1/1 [==============================] - 1s 1s/step - loss: 1.2716 - val_loss: 1.6396
# 1/1 [==============================] - 1s 1s/step - loss: 1.5032 - val_loss: 1.4691
# 1/1 [==============================] - 1s 1s/step - loss: 1.0969 - val_loss: 1.9127
# 1/1 [==============================] - 2s 2s/step - loss: 1.4716 - val_loss: 1.9722
# 1/1 [==============================] - 1s 1s/step - loss: 1.7014 - val_loss: 1.4691
# 1/1 [==============================] - 1s 1s/step - loss: 1.4055 - val_loss: 1.0075
# 1/1 [==============================] - 1s 1s/step - loss: 1.2235 - val_loss: 1.5483
# 1/1 [==============================] - 1s 1s/step - loss: 1.9393 - val_loss: 1.1269
# 1/1 [==============================] - 2s 2s/step - loss: 1.6224 - val_loss: 1.1728
# 1/1 [==============================] - 2s 2s/step - loss: 1.9052 - val_loss: 3.4958
# 1/1 [==============================] - 1s 1s/step - loss: 1.2407 - val_loss: 0.9709
# 1/1 [==============================] - 1s 1s/step - loss: 1.5683 - val_loss: 1.7746
# 1/1 [==============================] - 1s 1s/step - loss: 1.4366 - val_loss: 2.1818
# 1/1 [==============================] - 1s 1s/step - loss: 1.4967 - val_loss: 1.1020
# 1/1 [==============================] - 2s 2s/step - loss: 1.5954 - val_loss: 1.2833
# 1/1 [==============================] - 1s 1s/step - loss: 2.1848 - val_loss: 1.4022
# 1/1 [==============================] - 1s 1s/step - loss: 2.3063 - val_loss: 1.5304
# 1/1 [==============================] - 1s 1s/step - loss: 1.5362 - val_loss: 1.2857
# 1/1 [==============================] - 1s 1s/step - loss: 1.4993 - val_loss: 1.6534
# 1/1 [==============================] - 1s 1s/step - loss: 1.9149 - val_loss: 0.9392
# 1/1 [==============================] - 1s 1s/step - loss: 1.5513 - val_loss: 0.9146
# 1/1 [==============================] - 2s 2s/step - loss: 1.4998 - val_loss: 1.5873
# 1/1 [==============================] - 1s 1s/step - loss: 1.2917 - val_loss: 1.1557
# 1/1 [==============================] - 1s 1s/step - loss: 1.4145 - val_loss: 1.5032
# 1/1 [==============================] - 1s 1s/step - loss: 1.3324 - val_loss: 1.7638
# 1/1 [==============================] - 1s 1s/step - loss: 1.5034 - val_loss: 1.5888
# 1/1 [==============================] - 1s 1s/step - loss: 1.2946 - val_loss: 1.1289
# 1/1 [==============================] - 1s 1s/step - loss: 1.1659 - val_loss: 1.6025
# 1/1 [==============================] - 2s 2s/step - loss: 1.4191 - val_loss: 1.3166
# 1/1 [==============================] - 1s 1s/step - loss: 1.0496 - val_loss: 1.6400
# 1/1 [==============================] - 1s 1s/step - loss: 1.4626 - val_loss: 1.3633
# 1/1 [==============================] - 1s 1s/step - loss: 1.3434 - val_loss: 1.2145
# 1/1 [==============================] - 1s 1s/step - loss: 1.4249 - val_loss: 1.6107
# 1/1 [==============================] - 2s 2s/step - loss: 1.1711 - val_loss: 1.1585
# 1/1 [==============================] - 1s 1s/step - loss: 1.5851 - val_loss: 1.2015
# 1/1 [==============================] - 1s 1s/step - loss: 1.3957 - val_loss: 1.4065
# 1/1 [==============================] - 1s 1s/step - loss: 1.6882 - val_loss: 1.5689
# 1/1 [==============================] - 1s 1s/step - loss: 1.3459 - val_loss: 1.2237
# 1/1 [==============================] - 1s 1s/step - loss: 1.7601 - val_loss: 2.7828
# 1/1 [==============================] - 2s 2s/step - loss: 1.5073 - val_loss: 2.5799
# 1/1 [==============================] - 1s 1s/step - loss: 1.1084 - val_loss: 3.3770
# 1/1 [==============================] - 1s 1s/step - loss: 1.5171 - val_loss: 1.2367
# File 3/12 loaded
# 1/1 [==============================] - 1s 1s/step - loss: 1.6224 - val_loss: 0.8557
# 1/1 [==============================] - 1s 1s/step - loss: 1.3403 - val_loss: 1.5384
# 1/1 [==============================] - 1s 1s/step - loss: 1.0817 - val_loss: 1.0484
# 1/1 [==============================] - 2s 2s/step - loss: 2.0361 - val_loss: 1.2180
# 1/1 [==============================] - 1s 1s/step - loss: 1.1709 - val_loss: 1.0094
# 1/1 [==============================] - 1s 1s/step - loss: 1.5646 - val_loss: 6.1020
# 1/1 [==============================] - 1s 1s/step - loss: 1.8157 - val_loss: 1.1948
# 1/1 [==============================] - 1s 1s/step - loss: 1.3097 - val_loss: 1.5400
# 1/1 [==============================] - 2s 2s/step - loss: 1.3788 - val_loss: 1.3894
# 1/1 [==============================] - 2s 2s/step - loss: 1.4442 - val_loss: 1.7043
# 1/1 [==============================] - 1s 1s/step - loss: 1.4552 - val_loss: 1.1701
# 1/1 [==============================] - 1s 1s/step - loss: 1.4061 - val_loss: 1.6916
# 1/1 [==============================] - 1s 1s/step - loss: 1.6775 - val_loss: 1.6972
# 1/1 [==============================] - 1s 1s/step - loss: 1.2950 - val_loss: 1.5570
# 1/1 [==============================] - 1s 1s/step - loss: 1.3747 - val_loss: 1.1457
# 1/1 [==============================] - 2s 2s/step - loss: 1.3993 - val_loss: 1.6804
# 1/1 [==============================] - 1s 1s/step - loss: 1.7696 - val_loss: 0.7477
# 1/1 [==============================] - 1s 1s/step - loss: 1.2990 - val_loss: 1.2826
# 1/1 [==============================] - 1s 1s/step - loss: 1.2156 - val_loss: 1.2834
# 1/1 [==============================] - 1s 1s/step - loss: 1.8796 - val_loss: 1.1214
# 1/1 [==============================] - 1s 1s/step - loss: 1.4370 - val_loss: 1.2171
# 1/1 [==============================] - 2s 2s/step - loss: 1.8157 - val_loss: 1.4352
# 1/1 [==============================] - 2s 2s/step - loss: 1.8020 - val_loss: 1.7930
# 1/1 [==============================] - 1s 1s/step - loss: 1.6068 - val_loss: 1.3232
# 1/1 [==============================] - 1s 1s/step - loss: 1.7506 - val_loss: 1.3031
# 1/1 [==============================] - 1s 1s/step - loss: 1.3398 - val_loss: 1.1554
# 1/1 [==============================] - 1s 1s/step - loss: 1.6191 - val_loss: 2.4161
# 1/1 [==============================] - 2s 2s/step - loss: 1.4951 - val_loss: 1.5638
# 1/1 [==============================] - 1s 1s/step - loss: 1.5984 - val_loss: 1.4337
# 1/1 [==============================] - 1s 1s/step - loss: 1.3143 - val_loss: 3.1122
# 1/1 [==============================] - 1s 1s/step - loss: 1.7805 - val_loss: 2.4907
# 1/1 [==============================] - 1s 1s/step - loss: 1.3438 - val_loss: 1.0893
# 1/1 [==============================] - 1s 1s/step - loss: 1.2375 - val_loss: 1.8311
# 1/1 [==============================] - 2s 2s/step - loss: 1.9655 - val_loss: 1.3846
# 1/1 [==============================] - 1s 1s/step - loss: 1.4644 - val_loss: 1.4109
# 1/1 [==============================] - 1s 1s/step - loss: 1.3759 - val_loss: 2.6832
# 1/1 [==============================] - 1s 1s/step - loss: 1.9112 - val_loss: 1.2804
# 1/1 [==============================] - 1s 1s/step - loss: 1.4790 - val_loss: 1.8189
# 1/1 [==============================] - 1s 1s/step - loss: 1.2990 - val_loss: 1.6215
# 1/1 [==============================] - 2s 2s/step - loss: 1.2681 - val_loss: 0.7356
# 1/1 [==============================] - 2s 2s/step - loss: 1.3530 - val_loss: 2.1482
# 1/1 [==============================] - 1s 1s/step - loss: 1.4126 - val_loss: 1.4118
# 1/1 [==============================] - 1s 1s/step - loss: 1.3007 - val_loss: 1.3638
# 1/1 [==============================] - 1s 1s/step - loss: 1.7978 - val_loss: 1.2154
# 1/1 [==============================] - 1s 1s/step - loss: 1.3475 - val_loss: 1.8508
# 1/1 [==============================] - 2s 2s/step - loss: 1.2254 - val_loss: 1.6016
# 1/1 [==============================] - 2s 2s/step - loss: 1.5148 - val_loss: 1.4196
# 1/1 [==============================] - 1s 1s/step - loss: 2.0528 - val_loss: 1.3276
# 1/1 [==============================] - 1s 1s/step - loss: 1.0269 - val_loss: 1.1148
# File 4/12 loaded
# 1/1 [==============================] - 3s 3s/step - loss: 1.3807 - val_loss: 0.8862
# 1/1 [==============================] - 3s 3s/step - loss: 1.5209 - val_loss: 1.4769
# 1/1 [==============================] - 3s 3s/step - loss: 1.8224 - val_loss: 1.4496
# 1/1 [==============================] - 3s 3s/step - loss: 1.5645 - val_loss: 1.2898
# 1/1 [==============================] - 3s 3s/step - loss: 1.8097 - val_loss: 0.7234
# 1/1 [==============================] - 4s 4s/step - loss: 1.2053 - val_loss: 1.9843
# 1/1 [==============================] - 3s 3s/step - loss: 1.8913 - val_loss: 1.3838
# 1/1 [==============================] - 3s 3s/step - loss: 1.4915 - val_loss: 1.2569
# 1/1 [==============================] - 3s 3s/step - loss: 2.1276 - val_loss: 0.9853
# 1/1 [==============================] - 1s 1s/step - loss: 2.2187 - val_loss: 1.1132
# 1/1 [==============================] - 1s 1s/step - loss: 1.4815 - val_loss: 4.3052
# 1/1 [==============================] - 1s 1s/step - loss: 1.4407 - val_loss: 1.6109
# 1/1 [==============================] - 1s 1s/step - loss: 1.1844 - val_loss: 1.7926
# 1/1 [==============================] - 1s 1s/step - loss: 1.3136 - val_loss: 1.7169
# 1/1 [==============================] - 1s 1s/step - loss: 1.2174 - val_loss: 1.3391
# 1/1 [==============================] - 2s 2s/step - loss: 1.7331 - val_loss: 1.4393
# 1/1 [==============================] - 2s 2s/step - loss: 1.5238 - val_loss: 1.8146
# 1/1 [==============================] - 1s 1s/step - loss: 1.1804 - val_loss: 1.7281
# 1/1 [==============================] - 1s 1s/step - loss: 1.7381 - val_loss: 1.1571
# 1/1 [==============================] - 1s 1s/step - loss: 1.6563 - val_loss: 1.3825
# 1/1 [==============================] - 1s 1s/step - loss: 1.4796 - val_loss: 1.5860
# 1/1 [==============================] - 2s 2s/step - loss: 1.5801 - val_loss: 1.1467
# 1/1 [==============================] - 2s 2s/step - loss: 1.2430 - val_loss: 2.6361
# 1/1 [==============================] - 1s 1s/step - loss: 1.7324 - val_loss: 1.4612
# 1/1 [==============================] - 1s 1s/step - loss: 2.6591 - val_loss: 1.6367
# 1/1 [==============================] - 1s 1s/step - loss: 1.6763 - val_loss: 1.2181
# 1/1 [==============================] - 1s 1s/step - loss: 1.4685 - val_loss: 1.9076
# 1/1 [==============================] - 2s 2s/step - loss: 1.2577 - val_loss: 1.4829
# 1/1 [==============================] - 2s 2s/step - loss: 1.5524 - val_loss: 2.3523
# 1/1 [==============================] - 1s 1s/step - loss: 1.4410 - val_loss: 4.0304
# 1/1 [==============================] - 1s 1s/step - loss: 2.0161 - val_loss: 1.8770
# 1/1 [==============================] - 1s 1s/step - loss: 1.6475 - val_loss: 1.5023
# 1/1 [==============================] - 1s 1s/step - loss: 1.5569 - val_loss: 1.7089
# 1/1 [==============================] - 1s 1s/step - loss: 1.2639 - val_loss: 1.5970
# 1/1 [==============================] - 2s 2s/step - loss: 1.8678 - val_loss: 2.3373
# 1/1 [==============================] - ETA: 0s - loss: 1.7147
